# %% [markdown]
# <a href="https://colab.research.google.com/github/BhaveshNikam09/Deep_learning_practise/blob/main/linear_with_optimizers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import tensorflow as tf
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta, Nadam,Ftrl,Adamax
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
(X_train,y_train),(X_test,y_test)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train=X_train.reshape(-1,784)
X_test = X_test.reshape(-1, 784)

# %%
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
print("y_train original shape:", y_train.shape)
# Out:
# y_train original shape: (60000, 10)

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %% [markdown]
# # **1.Linear+Adam**

# %%
model=Sequential([
    Dense(512, input_shape=(784,)),
    Activation('linear'),
    Dense(256),
    Activation('linear'),
    Dense(10),
    Activation('softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer1=Adam()
model.compile(optimizer=optimizer1,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train, y_train, epochs=25, verbose=1, validation_split=0.15)
# Out:
# Epoch 1/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8501 - loss: 0.5081 - val_accuracy: 0.9093 - val_loss: 0.3221
# Epoch 2/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8975 - loss: 0.3610 - val_accuracy: 0.9204 - val_loss: 0.2884
# Epoch 3/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9067 - loss: 0.3271 - val_accuracy: 0.9193 - val_loss: 0.2921
# Epoch 4/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9083 - loss: 0.3237 - val_accuracy: 0.9140 - val_loss: 0.3132
# Epoch 5/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9114 - loss: 0.3141 - val_accuracy: 0.9204 - val_loss: 0.2775
# Epoch 6/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9133 - loss: 0.3040 - val_accuracy: 0.9207 - val_loss: 0.2980
# Epoch 7/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9159 - loss: 0.2927 - val_accuracy: 0.9199 - val_loss: 0.2832
# Epoch 8/25
# ...

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()

# %% [markdown]
# # **2.Linear + SGD**

# %%
model=Sequential([
    Dense(512, input_shape=(784,)),
    Activation('linear'),
    Dense(256),
    Activation('linear'),
    Dense(10),
    Activation('softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer2=SGD()
model.compile(optimizer=optimizer2,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=25,verbose=1,validation_split=0.15)
# Out:
# Epoch 1/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9291 - loss: 0.2562 - val_accuracy: 0.9322 - val_loss: 0.2536
# Epoch 2/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9291 - loss: 0.2525 - val_accuracy: 0.9298 - val_loss: 0.2545
# Epoch 3/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9297 - loss: 0.2514 - val_accuracy: 0.9314 - val_loss: 0.2498
# Epoch 4/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9292 - loss: 0.2489 - val_accuracy: 0.9316 - val_loss: 0.2505
# Epoch 5/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9288 - loss: 0.2535 - val_accuracy: 0.9293 - val_loss: 0.2559
# Epoch 6/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9309 - loss: 0.2493 - val_accuracy: 0.9288 - val_loss: 0.2589
# Epoch 7/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9302 - loss: 0.2478 - val_accuracy: 0.9296 - val_loss: 0.2511
# Epoch 8/25
# ...

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()

# %% [markdown]
# # **3.Linear + RMSProp**

# %%
model=Sequential([
    Dense(512, input_shape=(784,)),
    Activation('linear'),
    Dense(256),
    Activation('linear'),
    Dense(10),
    Activation('softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer3=RMSprop()
model.compile(optimizer=optimizer3,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=25,validation_split=0.15)
# Out:
# Epoch 1/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - accuracy: 0.8415 - loss: 0.5476 - val_accuracy: 0.8819 - val_loss: 0.3823
# Epoch 2/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8973 - loss: 0.3644 - val_accuracy: 0.9092 - val_loss: 0.3356
# Epoch 3/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9030 - loss: 0.3358 - val_accuracy: 0.9217 - val_loss: 0.2831
# Epoch 4/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9087 - loss: 0.3261 - val_accuracy: 0.9238 - val_loss: 0.2823
# Epoch 5/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9113 - loss: 0.3189 - val_accuracy: 0.9254 - val_loss: 0.2719
# Epoch 6/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9140 - loss: 0.3156 - val_accuracy: 0.9151 - val_loss: 0.2983
# Epoch 7/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9158 - loss: 0.3009 - val_accuracy: 0.9192 - val_loss: 0.2915
# Epoch 8/25
# ...

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()

# %% [markdown]
# # **4.Linear + Adagrad**

# %%
model=Sequential([
    Dense(512, input_shape=(784,)),
    Activation('linear'),
    Dense(256),
    Activation('linear'),
    Dense(10),
    Activation('softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer4=Adagrad()
model.compile(optimizer=optimizer4,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=25,validation_split=0.15)
# Out:
# Epoch 1/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7094 - loss: 1.0695 - val_accuracy: 0.8908 - val_loss: 0.4045
# Epoch 2/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8817 - loss: 0.4331 - val_accuracy: 0.9041 - val_loss: 0.3406
# Epoch 3/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8944 - loss: 0.3799 - val_accuracy: 0.9111 - val_loss: 0.3173
# Epoch 4/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9007 - loss: 0.3546 - val_accuracy: 0.9133 - val_loss: 0.3035
# Epoch 5/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9043 - loss: 0.3384 - val_accuracy: 0.9170 - val_loss: 0.2954
# Epoch 6/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9079 - loss: 0.3249 - val_accuracy: 0.9178 - val_loss: 0.2896
# Epoch 7/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9091 - loss: 0.3180 - val_accuracy: 0.9198 - val_loss: 0.2858
# Epoch 8/25
# ...

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()

# %% [markdown]
# # **5.Linear + Adadelta**

# %%
model=Sequential([
    Dense(512, input_shape=(784,)),
    Activation('linear'),
    Dense(256),
    Activation('linear'),
    Dense(10),
    Activation('softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer5=Adadelta()
model.compile(optimizer=optimizer5,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=25,validation_split=0.15)
# Out:
# Epoch 1/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2149 - loss: 2.2080 - val_accuracy: 0.6458 - val_loss: 1.5612
# Epoch 2/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6719 - loss: 1.4532 - val_accuracy: 0.7867 - val_loss: 1.0846
# Epoch 3/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7713 - loss: 1.0609 - val_accuracy: 0.8319 - val_loss: 0.8307
# Epoch 4/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8106 - loss: 0.8441 - val_accuracy: 0.8519 - val_loss: 0.6870
# Epoch 5/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8294 - loss: 0.7231 - val_accuracy: 0.8657 - val_loss: 0.5982
# Epoch 6/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8435 - loss: 0.6408 - val_accuracy: 0.8749 - val_loss: 0.5391
# Epoch 7/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8531 - loss: 0.5885 - val_accuracy: 0.8811 - val_loss: 0.4971
# Epoch 8/25
# ...

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()

# %% [markdown]
# # **6.Linear + Nadam**

# %%
model=Sequential([
    Dense(512, input_shape=(784,)),
    Activation('linear'),
    Dense(256),
    Activation('linear'),
    Dense(10),
    Activation('softmax')
])

# %%
optimizer6=Nadam()
model.compile(optimizer=optimizer6,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=25,validation_split=0.15)
# Out:
# Epoch 1/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8588 - loss: 0.4831 - val_accuracy: 0.9102 - val_loss: 0.3080
# Epoch 2/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9036 - loss: 0.3366 - val_accuracy: 0.9024 - val_loss: 0.3357
# Epoch 3/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9097 - loss: 0.3205 - val_accuracy: 0.9144 - val_loss: 0.3057
# Epoch 4/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9120 - loss: 0.3159 - val_accuracy: 0.9159 - val_loss: 0.3028
# Epoch 5/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9126 - loss: 0.3032 - val_accuracy: 0.9239 - val_loss: 0.2862
# Epoch 6/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9146 - loss: 0.2978 - val_accuracy: 0.9161 - val_loss: 0.2928
# Epoch 7/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9175 - loss: 0.2933 - val_accuracy: 0.9236 - val_loss: 0.2734
# Epoch 8/25
# ...

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()

# %% [markdown]
# # **7.Linear + Ftrl**

# %%
model=Sequential([
    Dense(512, input_shape=(784,)),
    Activation('linear'),
    Dense(256),
    Activation('linear'),
    Dense(10),
    Activation('softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optmizier6=Ftrl()
model.compile(optimizer=optmizier6,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=25,validation_split=0.15)
# Out:
# Epoch 1/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.1105 - loss: 2.3038 - val_accuracy: 0.1063 - val_loss: 2.3023
# Epoch 2/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1147 - loss: 2.3022 - val_accuracy: 0.1063 - val_loss: 2.3023
# Epoch 3/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.1129 - loss: 2.3021 - val_accuracy: 0.1063 - val_loss: 2.3022
# Epoch 4/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1145 - loss: 2.3019 - val_accuracy: 0.1063 - val_loss: 2.3022
# Epoch 5/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.1127 - loss: 2.3019 - val_accuracy: 0.1063 - val_loss: 2.3021
# Epoch 6/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.1125 - loss: 2.3019 - val_accuracy: 0.1063 - val_loss: 2.3021
# Epoch 7/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1136 - loss: 2.3018 - val_accuracy: 0.1063 - val_loss: 2.3021
# Epoch 8/25
# ...

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()

# %% [markdown]
# # **8.Linear + Adamax**

# %%
model=Sequential([
    Dense(512, input_shape=(784,)),
    Activation('linear'),
    Dense(256),
    Activation('linear'),
    Dense(10),
    Activation('softmax')
])

# %%
optimizer8=Adamax()
model.compile(optimizer=optimizer8,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=25,validation_split=0.15)
# Out:
# Epoch 1/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8604 - loss: 0.4614 - val_accuracy: 0.9138 - val_loss: 0.3071
# Epoch 2/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9078 - loss: 0.3218 - val_accuracy: 0.9153 - val_loss: 0.2924
# Epoch 3/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9149 - loss: 0.3056 - val_accuracy: 0.9208 - val_loss: 0.2755
# Epoch 4/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9159 - loss: 0.2948 - val_accuracy: 0.9204 - val_loss: 0.2795
# Epoch 5/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9200 - loss: 0.2905 - val_accuracy: 0.9241 - val_loss: 0.2757
# Epoch 6/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9191 - loss: 0.2856 - val_accuracy: 0.9230 - val_loss: 0.2710
# Epoch 7/25
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9224 - loss: 0.2791 - val_accuracy: 0.9242 - val_loss: 0.2731
# Epoch 8/25
# ...

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()
